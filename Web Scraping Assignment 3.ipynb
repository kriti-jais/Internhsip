# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementNotInteractableException, SessionNotCreatedException, TimeoutException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# Question.10)Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews,
# overall reviews, privates from price, dorms from price, facilities and property description.

# %%
driver=webdriver.Chrome(r"C:\Users\jaisw\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.hostelworld.com")

# %%
location=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[1]/div/div/div/input')
location.send_keys("London")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[5]/button')
search.click()

# %%
locsearch=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[5]/button')
locsearch.click()

# %%
 hostel name, distance from city centre, ratings, total reviews,
overall reviews, privates from price, dorms from price, facilities and property description

# %%
hostel_name=[]
try:
    for i in driver.find_elements(By.XPATH,'//h2[@class="title title-6"]'):
        hostel_name.append(i.text)
except NoSuchElementException:
    hostel_name.append("-")

# %%
len(hostel_name)
# Out:
# 30

# %%
distance=[]
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="description"]'):
        distance.append(i.text)
except NoSuchElementException:
    distance.append("-")

# %%
len(distance)
# Out:
# 30

# %%
ratings=[]
try:
    for i in driver.find_elements(By.XPATH,'//div[@class="score orange big"]'):
        ratings.append(i.text)
except NoSuchElementException:
    ratings.append("-")

# %%
len(ratings)
# Out:
# 28

# %%
total_reviews=[]
try:
    for i in driver.find_elements(By.XPATH,'//div[@class="reviews"]'):
        total_reviews.append(i.text)
except NoSuchElementException:
    total_reviews.append("-")

# %%
len(total_reviews)
# Out:
# 30

# %%
overall_reviews=[]
try:
    for i in driver.find_elements(By.XPATH,'//div[@class="keyword"]'):
        overall_reviews.append(i.text)
        
except NoSuchElementException:
    overall_reviews.append("-")

# %%
len(overall_reviews)
# Out:
# 32

# %%
property_url=[]

for i in driver.find_elements(By.XPATH,'//a[@class]'):
    property_url.append(i.get_attribute('href'))

# %%
property_url
# Out:
# ['https://www.hostelworld.com/',
#  'https://global.hostelworld.com/travel-deals',
#  'https://global.hostelworld.com/travel-deals#terms-and-conditions',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Wombat-s-City-Hostel-London/London/88047?from=2023-02-02&to=2023-02-05&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Wombat-s-City-Hostel-London/London/88047?from=2023-02-02&to=2023-02-05&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Wombat-s-City-Hostel-London/London/88047?from=2023-02-02&to=2023-02-05&guests=2&display=reviews',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Wombat-s-City-Hostel-London/London/88047?from=2023-02-02&to=2023-02-05&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Village/London/502?from=2023-02-02&to=2023-02-05&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Village/London/502?from=2023-02-02&to=2023-02-05&guests=2',
# ...

# %%
psearch=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[4]/div/div/div[4]/div[4]/a[2]/button')
psearch.click()

# %%
hostel_name1=[]
distance1=[]
facilty1=[]
ratings1=[]
overall1=[]
pprice1=[]

Details=[i.text.split('\n') for i in driver.find_elements(By.XPATH,'//div[@class="property"]')]

try:
    for i in Details:
        hostel_name1.append(i[0])
        distance1.append(i[1])
        
except NoSuchElementException:
    hostel_name1.append('-')
    distance1.append('-')

# %%
facilty2=[]
Details=[i.text.split('\n') for i in driver.find_elements(By.XPATH,'//div[@class="facilities-label facilities"]')]
try:
    for i in Details:
        facilty2.append(i)
        
except NoSuchElementException:
    facilty2.append('-')

# %%
pprice=[]
dprice=[]
Details=[i.text.split('\n') for i in driver.find_elements(By.XPATH,'//a[@class="prices"]')]
try:
    for i in Details:
        dprice.append(i[-1])
        pprice.append(i[0])
        
except NoSuchElementException:
    pprice.append('-')
    dprice.append('-')

# %%
df1=pd.DataFrame({'HostelName':hostel_name1[0:28],"Distance from city center":distance1[0:28],'Facilities':facilty2[0:28],'Ratings':ratings[0:28],'Overall reviews':overall_reviews[0:28],'Privates from price':pprice[0:28],'Dorms from price':dprice[0:28]})
df1
# Out:
#                                  HostelName  \
# 0               Wombat's City Hostel London
# 1                  St Christopher's Village
# 2               Wombat's City Hostel London
# 3                  St Christopher's Village
# 4                   Hostel One Notting Hill
# 5                          Generator London
# 6                      Urbany Hostel London
# 7         Safestay London Elephant & Castle
# 8               Smart Russell Square Hostel
# 9                          NX London Hostel
# 10       Destinations Hostels @ The Gallery
# 11  Safestay London Kensington Holland Park
# 12                  St Christopher's Camden
# 13                       No.8 Seven Sisters
# 14             No.8 Willesden Hostel London
# 15                  Smart Camden Inn Hostel
# 16                           Phoenix Hostel
# 17             St Christopher's Hammersmith
# 18                  Queen Elizabeth Chelsea
# 19                 Barmy Badger Backpackers
# ...

# %%
df1.to_csv("file.csv")

# %%
driver.close()

# %% [markdown]
# Question.9) Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted
# from any YouTube Video.

# %%
driver=webdriver.Chrome(r"C:\Users\jaisw\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.youtube.com")

# %%
Search=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/input')
Search.send_keys(" Comment upvote and time")

# %%
search=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/button/yt-icon')
search.click()

# %% [markdown]
# Question.8) Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be
# scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver=webdriver.Chrome(r"C:\Users\jaisw\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.forbes.com")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[1]/div/div/div')
search.click()

# %%
bill=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[1]/div/div/div[2]/ul/li[1]/div[1]')
bill.click()

# %%
billan=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[1]/div/div/div[2]/ul/li[1]/div[2]/div[2]/a')
billan.click()

# %%
billionaires=driver.find_element(By.XPATH,'/html/body/div[1]/main/div/section/section[1]/div/div/div[1]/div/div[1]/div[1]/div[2]/a/h2')
billionaires.click()

# %%
Rank=[]
Name=[]
Net_worth=[]
Age=[]
Citizenship=[]
Source=[]
Industry=[]
Details=[i.text.split('\n') for i in driver.find_elements(By.XPATH,'//div[@class="table-row "]')]

try:
    for i in Details:
        Rank.append(i[0])
        Name.append(i[1])
        Net_worth.append(i[2])
        Age.append(i[3])
        Citizenship.append(i[4])
except NoSuchElementException:
    Rank.append('-')
    Name.append('-')
    Net_worth.append('-')
    Age.append(i[3])
    Citizenship.append('-')

# %%
Detail=[i.text.split('\n') for i in driver.find_elements(By.XPATH,'//span[@class="source-text"]')]

try:
    for i in Detail:
        Source.append(i)
except NoSuchElementException:
    Source.append('-')

# %%
Detail=[i.text.split('\n') for i in driver.find_elements(By.XPATH,'//div[@class="category"]')]

try:
    for i in Detail:
        Industry.append(i)

except NoSuchElementException:
    Industry.append('-')

# %%
d4=pd.DataFrame({'Rank':Rank,'Name':Name,'Net_worth':Net_worth,'Age':Age,'Citizenship':Citizenship,'Source':Source,'Industry':Industry})
d4
# Out:
#      Rank                      Name Net_worth Age    Citizenship  \
# 0      1.                 Elon Musk    $219 B  50  United States
# 1      2.                Jeff Bezos    $171 B  58  United States
# 2      3.  Bernard Arnault & family    $158 B  73         France
# 3      4.                Bill Gates    $129 B  66  United States
# 4      5.            Warren Buffett    $118 B  91  United States
# ..    ...                       ...       ...  ..            ...
# 195  192.    Marcel Herrmann Telles   $10.3 B  72         Brazil
# 196  197.                Leon Black     $10 B  70  United States
# 197  197.                Joe Gebbia     $10 B  40  United States
# 198  197.              David Geffen     $10 B  79  United States
# 199  197.                Yu Renrong     $10 B  56          China
#
#                       Source                 Industry
# 0            [Tesla, SpaceX]             [Automotive]
# 1                   [Amazon]             [Technology]
# ...

# %%
d4.to_csv("file1.csv")

# %%
driver.close()

# %% [markdown]
# Question.7) Write a program to scrap all the available details of best gaming laptops from digit.in

# %%
driver=webdriver.Chrome(r"C:\Users\jaisw\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.digit.in")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[2]/div/ul/li[5]/a')
search.click()

# %%
gaminglap=driver.find_element(By.XPATH,'/html/body/div[2]/div/ul/li[5]/div[3]/div/div[2]/div/ul[3]/li[4]/a')
gaminglap.click()

# %%
Category=[]
Description=[]
Detail=[i.text.split('\n') for i in driver.find_elements(By.XPATH,'//div[@class="article_row"]')]

try:
    for i in Detail:
        Category.append(i[0])
        Description.append(i[2])
except NoSuchElementException:
    Category.append('-')
    Description.append('-')

# %%
Image=[]
for i in driver.find_elements(By.XPATH,'//img[@class="lzy_img"]'):
    Image.append(i.get_attribute('src'))

# %%
df2=pd.DataFrame({'Category':Category,'Description':Description,})
df2
# Out:
#                               Category  \
# 0    Best Asus Gaming Laptops in India
# 1  Best Gaming Laptops Under Rs 50,000
# 2       Best HP Gaming Laptop in India
# 3              Best Dell Gaming Laptop
# 4  Best Gaming Laptops Under Rs. 60000
# 5  Best Lenovo Gaming Laptops in India
# 6  Best Gaming Laptops under Rs. 40000
# 7     Best MSI Gaming Laptops in India
# 8    Best Gaming Laptops under ₹70,000
# 9     Best Gaming Laptops under 1 Lakh
#
#                                          Description
# 0  <p>ASUS is a technical powerhouse and makes so...
# 1  If you’re in the market for a gaming laptop, t...
# 2  HP has been in the laptop market for a long ti...
# 3  Dell is a brand that is synonymous with gaming...
# 4  These days, buying a gaming laptop under 60000...
# 5  Lenovo is one of the biggest laptop manufactur...
# 6  Truth be told there aren’t any true gaming lap...
# 7  There are a lot of laptop OEMs in the market b...
# ...

# %%
df2.to_csv('file3.csv')

# %%
driver.close()

# %% [markdown]
# Question.5) Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google
# maps.

# %%
driver=webdriver.Chrome(r"C:\Users\jaisw\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.google.com/maps")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/form/div[2]/div[3]/div/input[1]')
search.send_keys("Lucknow")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/div[1]/button')
search.click()

# %%
googlemap=[]
for i in driver.find_elements(By.XPATH,"/html/body/div[3]/div[9]/div[23]/div[1]/div[2]/div[2]/div/div[2]/div[3]/button"):
    googlemap.append(i.text)

# %%
googlemap
# Out:
# ['26.805950, 80.885490']

# %%
driver.close()

# %% [markdown]
# Question.4) Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be
# scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
driver=webdriver.Chrome(r"C:\Users\jaisw\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.flipkart.com")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
search.send_keys("Oneplus Nord, pixel 4A")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
search.click()

# %%
BrandName=[]
SmartphoneName=[]
Colour=[]
RAM=[]
ROM=[]
PrimaryCamera=[]
SecondaryCamera=[]
DisplaySize=[]
BatteryCapacity=[]
ProductURL=[]

Detail=[i.text.split('\n') for i in driver.find_elements(By.XPATH,'//div[@class="col col-7-12"]')]

try:
    for i in Detail:
        BrandName.append(i[0])
        SmartphoneName.append(i[1])
        Colour.append(i[2])
        DisplaySize.append(i[3])
        ROM.append(i[4])
        PrimaryCamera.append(i[5])
        SecondaryCamera.append(i[6])
except NoSuchElementException:
    BrandName.append("-")
    SmartphoneName.append("-")
    Colour.append("-")
    DisplaySize.append("-")
    ROM.append("-")
    PrimaryCamera.append("-")
    SecondaryCamera.append("-")

# %%
BrandName=[]
Smartphone=[]
Colou=[]
RAM=[]
ROM=[]
PCamera=[]
SCamera=[]
DisplaySize=[]
BatCap=[]

# %%
Product_url=[]
for i in driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]'):
    Product_url.append(i.get_attribute('href'))

# %%
brand=[]

# %%
for i in Product_url:
    driver.get(i)
    time.sleep(2)
    try:
        br=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[3]/div/div[1]/h1/span')
        brand.append(br.text)
    except NoSuchElementException:
        brand.append("-")

# %%
for i in Product_url:
    driver.get(i)
    time.sleep(2)
    try:
        sp=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[10]/div[4]/div/div[2]/div/div[1]/table/tbody/tr[3]/td[2]/ul/li')
        Smartphone.append(sp.text)
    except NoSuchElementException:
        Smartphone.append("-")

# %%
for i in Product_url:
    driver.get(i)
    time.sleep(2)
    try:
        col=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[10]/div[4]/div/div[2]/div/div[1]/table/tbody/tr[4]/td[2]/ul/li')
        Colou.append(col.text)
    except NoSuchElementException:
        Colou.append("-")

# %%
for i in Product_url:
    driver.get(i)
    time.sleep(2)
    try:
        ram=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[10]/div/div/div[6]/div/div[2]/div[1]/div[4]/table/tbody/tr[2]/td[2]/ul/li')
        RAM.append(ram.text)
    except NoSuchElementException:
        RAM.append("-")

# %%
for i in Product_url:
    driver.get(i)
    time.sleep(2)
    try:
        rom=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[1]/div/div[2]/ul/li[1]')
        ROM.append(rom.text)
    except NoSuchElementException:
        ROM.append("-")

# %%
Pcam=[]
for i in Product_url:
    driver.get(i)
    time.sleep(2)
    try:
        pc=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[1]/div/div[2]/ul/li[3]')
        Pcam.append(pc.text)
    except NoSuchElementException:
        Pcam.append("-")

# %%
for i in Product_url:
    driver.get(i)
    time.sleep(2)
    try:
        sc=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[10]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[6]/td[2]/ul/li')
        SCamera.append(sc.text)
    except NoSuchElementException:
        SCamera.append("-")

# %%
for i in Product_url:
    driver.get(i)
    time.sleep(2)
    try:
        ds=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[1]/div/div[2]/ul/li[2]')
        DisplaySize.append(ds.text)
    except NoSuchElementException:
        DisplaySize.append("-")

# %%
df5=pd.DataFrame({"BrandName":brand[0:24],"SmartphoneName":Smartphone[0:24],"Colour":Colou[0:24],"RAM":RAM[0:24],"ROM":ROM[0:24],"PrimaryCamera":Pcam[0:24],"SecondryCamera":SCamera[0:24],"DisplaySize":DisplaySize[0:24],"BataryCapacity":BatCap[0:24],"Product_url":Product_url[0:24]})
df5
# Out:
#                                             BrandName  SmartphoneName  \
# 0             APPLE iPhone 14 Plus (Midnight, 128 GB)  iPhone 14 Plus
# 1            APPLE iPhone 14 Plus (Starlight, 128 GB)  iPhone 14 Plus
# 2         APPLE iPhone 14 Plus ((PRODUCT)RED, 128 GB)  iPhone 14 Plus
# 3             APPLE iPhone 14 Plus (Midnight, 256 GB)  iPhone 14 Plus
# 4             APPLE iPhone 14 Plus (Midnight, 512 GB)  iPhone 14 Plus
# 5         APPLE iPhone 14 Plus ((PRODUCT)RED, 512 GB)               -
# 6              OPPO F3 Plus (Gold, 64 GB)  (4 GB RAM)               -
# 7                 APPLE iPhone 14 Plus (Blue, 128 GB)  iPhone 14 Plus
# 8               APPLE iPhone 14 Plus (Purple, 128 GB)  iPhone 14 Plus
# 9             APPLE iPhone 8 Plus (Space Grey, 64 GB)               -
# 10                  APPLE iPhone 8 Plus (Gold, 64 GB)               -
# 11                APPLE iPhone 8 Plus (Silver, 64 GB)               -
# ...

# %%
df5.to_csv("file4.csv", index=False)

# %%
driver.close()

# %% [markdown]
# Question. 3) Write a python program to access the search bar and search button on images.google.com and scrape 10
# images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
driver=webdriver.Chrome(r"C:\Users\jaisw\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://images.google.com")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search.send_keys("fruits")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
search.click()

# %%
Image_url=[]
image=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in image:
    Image_url.append(i.get_attribute('src'))

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search.send_keys("cars")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
search.click()

# %%
cars_url=[]
image=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in image:
    cars_url.append(i.get_attribute('src'))

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search.send_keys("Machine Learning")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
search.click()

# %%
ML_url=[]
image=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in image:
    ML_url.append(i.get_attribute('src'))

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search.send_keys("Guitar")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
search.click()

# %%
Guitar_url=[]
image=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in image:
    Guitar_url.append(i.get_attribute('src'))

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search.send_keys("Cakes")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
search.click()

# %%
Cakes_url=[]
image=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in image:
    Cakes_url.append(i.get_attribute('src'))

# %%
driver.close()

# %% [markdown]
# Question. 1) Write a python program which searches all the product under a particular product from www.amazon.in.
# The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search
# for guitars.

# %%
driver=webdriver.Chrome(r"C:\Users\jaisw\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.amazon.in")

# %%
user_input=input("enter product name=")
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search.send_keys(user_input)
# Out:
# enter product name=carvan mini

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search.click()

# %% [markdown]
# Question. 2) In the above question, now scrape the following details of each product listed in first 3 pages of your
# search results and save it in a data frame and csv. In case if any product has less than 3 pages in search
# results then scrape all the products available under that product name. Details to be scraped are: "Brand
# Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
product_url=[]
start=0
end=3
for i in range(start,end):
    for i in driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]'):
        product_url.append(i.get_attribute('href'))

# %%
Brand=[]
ProductName=[]
Price=[]
Return_Ex=[]
Expected_Del=[]
Availability=[]

# %%
for i in product_url:
    driver.get(i)
    time.sleep(2)
    try:
        Br=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[6]/div[4]/div[4]/div[41]/div/table/tbody/tr[1]/td[2]/span')
        Brand.append(Br.text)
    except NoSuchElementException:
        Brand.append("-")

# %%
Brand
# Out:
# ['Fender',
#  'CEZO',
#  '-',
#  'Focusrite',
#  'Video Conference',
#  'VOX',
#  'VOX',
#  'VOX',
#  'Audio-Technica',
#  'Audient',
#  '-',
#  'HUMBLE',
#  'M-Audio',
#  '-',
#  '-',
#  'MAONO',
#  '-',
#  '-',
#  '-',
#  'MAONO',
#  'Focusrite',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Behringer',
#  'Soundcraft',
#  'YAMAHA',
#  '-',
#  '-',
#  '-',
#  'M-Audio',
#  '-',
#  '-',
#  'Focusrite',
#  'Behringer',
#  'Zoom',
#  'Behringer',
#  'Behringer',
#  'Behringer',
#  'MAONO',
#  'PreSonus',
#  'Focusrite',
#  'SAMSON',
#  'Blue Microphones',
#  'Audient',
#  '-',
#  'Zoom',
#  '-',
#  'Focusrite',
#  'IK Multimedia',
#  'Behringer',
#  '-',
#  'Fender',
#  'CEZO',
#  '-',
#  'Focusrite',
#  'Video Conference',
#  'VOX',
#  'VOX',
#  'VOX',
#  'Audio-Technica',
#  'Audient',
#  '-',
#  'HUMBLE',
#  'M-Audio',
#  '-',
#  '-',
#  'MAONO',
#  '-',
#  '-',
#  '-',
#  'MAONO',
#  'Focusrite',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Behringer',
#  'Soundcraft',
#  'YAMAHA',
# ...

# %%
for i in product_url:
    driver.get(i)
    time.sleep(2)
    try:
        PN=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[4]/div[4]/div[1]/div/h1')
        ProductName.append(PN.text)
    except NoSuchElementException:
        ProductName.append("-")

# %%
ProductName
# Out:
# ['-',
#  '-',
#  'F1Rni Headphone Guitar Amp Amplifier with 3.5mm Headphone Jack AUX Input Plug-and-Play ERNP',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  'ULTRAPROLINK UM1002 Sing Along Karaoke Bluetooth Mixer with Karaoke Microphone & Bluetooth Receiver Amplifier with Echo for Mobile Phones',
#  '-',
#  '-',
#  '-',
#  'PE100 Portable Multi-Effects Psor Guitar Effect Pedal 39 Effects 40 Drum Patterns 10 Metronomes Tap Tempo Huaishu',
#  '-',
#  'Veena/Violin Pickup & Small Mini Amplifier Combo by Supreme Musicals',
#  '-',
#  '-',
#  'Maono AU-WDM01 Professional Dynamic Cardioid Vocal Wired Microphone with XLR Cable (Black)',
#  '-',
#  'NUX Classic Rock Guitar Plug Headphone Amp',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Fender Mustang LT-25 - Digital Guitar Amplifier',
#  '-',
#  'TRONICA 30W CARWAAN - The 8 Inches Rechargeable Bluetooth Party Karaoke Home Theater System with Wired Microphone',
#  '-',
# ...

# %%
for i in product_url:
    driver.get(i)
    time.sleep(2)
    try:
        Pric=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[6]/div[4]/div[4]/div[10]/div[3]/div[1]/span[2]/span[2]/span[2]')
        Price.append(Pric.text)
    except NoSuchElementException:
        Price.append("-")

# %%
Price
# Out:
# ['-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '11,299',
# ...

# %%
for i in product_url:
    driver.get(i)
    time.sleep(2)
    try:
        exde=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[6]/div[4]/div[1]/div[3]/div/div[1]/div/div/div/form/div/div/div/div/div[3]/div/div[2]/div[9]/div[1]/div/div/div[1]/span/span')
        Expected_Del.append(exde.text)
    except NoSuchElementException:
        Expected_Del.append("-")

# %%
Expected_Del
# Out:
# ['Sunday, 5 February',
#  'Monday, 6 February',
#  '-',
#  'Sunday, 5 February',
#  'Sunday, 5 February',
#  '-',
#  '-',
#  '-',
#  'Thursday, 9 February',
#  'Sunday, 5 February',
#  '-',
#  'Sunday, 5 February',
#  'Sunday, 5 February',
#  '-',
#  '-',
#  'Sunday, 5 February',
#  '-',
#  '-',
#  'Wednesday, 8 February',
#  'Sunday, 5 February',
#  'Sunday, 5 February',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Tuesday, 7 February',
#  'Tuesday, 7 February',
#  'Sunday, 5 February',
#  'Wednesday, 8 February',
#  '-',
#  'Tuesday, 7 February',
#  '-',
#  'Sunday, 5 February',
#  '-',
#  'Tuesday, 7 February',
#  'February 28 - March 1',
#  'February 23 - 24',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Sunday, 5 February',
#  '-',
#  'Wednesday, 8 February',
#  'Tuesday, 7 February',
#  'Sunday, 5 February',
#  '-',
#  '-',
#  'Wednesday, 8 February',
#  'Friday, 10 February',
#  'Sunday, 5 February',
#  '-',
#  'Sunday, 5 February',
#  '-',
#  'Sunday, 5 February',
#  'Tuesday, 7 February',
# ...

# %%
for i in product_url:
    driver.get(i)
    time.sleep(2)
    try:
        re=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[6]/div[4]/div[4]/div[23]/div[2]/div/div/div/div[3]/span/div[2]/a')
        Return_Ex.append(re.text)
    except NoSuchElementException:
        Return_Ex.append("-")

# %%
Return_Ex
# Out:
# ['7 days Replacement',
#  '7 days Returnable',
#  '-',
#  '7 days Replacement',
#  '7 days Replacement',
#  '-',
#  '-',
#  '-',
#  '7 days Replacement',
#  '7 days Replacement',
#  '-',
#  '7 days Replacement',
#  '7 days Replacement',
#  '-',
#  '-',
#  '7 days Replacement',
#  '-',
#  '-',
#  '-',
#  '7 days Replacement',
#  '7 days Replacement',
#  '-',
#  '-',
#  '-',
#  '-',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '-',
#  '-',
#  '7 days Replacement',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '-',
#  '-',
#  '-',
#  '30 days Returnable',
#  '-',
#  '-',
#  '7 days Replacement',
#  '7 days Replacement',
#  '-',
#  '-',
#  '7 days Replacement',
#  '-',
#  '7 days Replacement',
#  '-',
#  '-',
#  '7 days Replacement',
#  '7 days Replacement',
#  '-',
#  '-',
#  '-',
#  '7 days Replacement',
#  '7 days Replacement',
#  '-',
# ...

# %%
for i in product_url:
    driver.get(i)
    time.sleep(2)
    try:
        avail=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[6]/div[4]/div[1]/div[3]/div/div[1]/div/div/div/form/div/div/div/div/div[3]/div/div[4]/div/div[1]/span')
        Availability.append(avail.text)
    except NoSuchElementException:
        Availability.append("-")

# %%
Availability
# Out:
# ['In stock.',
#  'In stock.',
#  '-',
#  'Only 1 left in stock.',
#  'In stock.',
#  '-',
#  '-',
#  '-',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  '-',
#  '-',
#  'In stock.',
#  '-',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  '-',
#  '-',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'Only 1 left in stock.',
#  '-',
#  'In stock.',
#  '-',
#  'Only 1 left in stock.',
#  '-',
#  'In stock.',
#  'Usually dispatched in 9 to 10 days.',
#  'Usually dispatched in 6 to 7 days.',
#  '-',
#  '-',
#  '-',
#  '-',
#  'In stock.',
#  '-',
#  'Only 1 left in stock.',
#  'Only 1 left in stock.',
#  'In stock.',
#  '-',
#  '-',
#  'In stock.',
#  'Only 1 left in stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  '-',
#  'Only 1 left in stock.',
#  'In stock.',
#  '-',
#  '-',
#  '-',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  '-',
#  '-',
#  'In stock.',
# ...

# %%
print(len(product_url),len(Brand),len(ProductName),len(Price),len(Return_Ex),len(Expected_Del),len(Availability))
# Out:
# 162 162 313 284 162 162 162

# %%
df6=pd.DataFrame({"Brand Name":Brand[0:162],"Product Name":ProductName[0:162],"Price":Price[0:162],"Return_Exchange":Return_Ex[0:162],"Expected Delivery":Expected_Del[0:162],"Availability":Availability[0:162],"Prodcut URL":product_url[0:162]})
df6
# Out:
#            Brand Name                                       Product Name  \
# 0              Fender                                                  -
# 1                CEZO                                                  -
# 2                   -  F1Rni Headphone Guitar Amp Amplifier with 3.5m...
# 3           Focusrite                                                  -
# 4    Video Conference                                                  -
# ..                ...                                                ...
# 157                 -                                                  -
# 158         Focusrite                                                  -
# 159     IK Multimedia                                                  -
# 160         Behringer                                                  -
# 161                 -  ULTRAPROLINK UM1002 Sing Along Karaoke Bluetoo...
#
#      Price     Return_Exchange     Expected Delivery           Availability  \
# ...

# %%
df6.to_csv("file6.csv", index=False)

# %%
driver.close()

# %%
driver=webdriver.Chrome(r"C:\Users\jaisw\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
Rank=[]
Title=[]
Author=[]
Volume_Sales=[]
Publisher=[]
Genre=[]
b=[]
c=[]

# %%
for i in driver.find_elements(By.XPATH,'//td[@class="last left"]'):
        b.append(i.text.split(",")[-1])

# %%
b
# Out:
# [' Thriller & Adventure',
#  "Children's Fiction",
#  "Children's Fiction",
#  "Children's Fiction",
#  'Romance & Sagas',
#  "Children's Fiction",
#  "Children's Fiction",
#  "Children's Fiction",
#  ' Thriller & Adventure',
#  "Children's Fiction",
#  'Romance & Sagas',
#  'Young Adult Fiction',
#  ' Thriller & Adventure',
#  'Romance & Sagas',
#  ' Thriller & Adventure',
#  'Young Adult Fiction',
#  ' Thriller & Adventure',
#  'Young Adult Fiction',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  ' Thriller & Adventure',
#  'Popular Science',
#  ' Thriller & Adventure',
#  'Young Adult Fiction',
#  'Picture Books',
#  'Picture Books',
#  'Food & Drink: General',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  ' Thriller & Adventure',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'Humour: Collections & General',
#  'General & Literary Fiction',
# ...

# %%
f=[]
for i in driver.find_elements(By.XPATH,'//th[@class="left bold"]'):
    f.append(i.text)

# %%
f
# Out:
# ['Rank', 'Title', 'Author', 'Volume Sales', 'Publisher']

# %%
Author
# Out:
# ['Rank',
#  'Title',
#  'Author',
#  'Volume Sales',
#  'Publisher',
#  "2 Harry Potter and the Deathly Hallows Rowling, J.K. 4,475,152 Bloomsbury Children's Fiction",
#  "4 Harry Potter and the Order of the Phoenix Rowling, J.K. 4,179,479 Bloomsbury Children's Fiction",
#  "6 Harry Potter and the Goblet of Fire Rowling, J.K. 3,583,215 Bloomsbury Children's Fiction",
#  "8 Harry Potter and the Prisoner of Azkaban Rowling, J.K. 3,377,906 Bloomsbury Children's Fiction",
#  "10 Harry Potter and the Half-blood Prince:Children's Edition Rowling, J.K. 2,950,264 Bloomsbury Children's Fiction",
#  '12 Twilight Meyer, Stephenie 2,315,405 Little, Brown Book Young Adult Fiction',
#  '14 Fifty Shades Freed James, E. L. 2,193,928 Random House Romance & Sagas',
#  '16 New Moon Meyer, Stephenie 2,152,737 Little, Brown Book Young Adult Fiction',
#  '18 Eclipse Meyer, Stephenie 2,052,876 Little, Brown Book Young Adult Fiction',
# ...
