# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementNotInteractableException, SessionNotCreatedException, TimeoutException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.webdriver import ActionChains

# %% [markdown]
# Question.2) Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.

# %%
driver=webdriver.Chrome(r"C:\Users\jaisw\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.bcci.tv")

# %%
from selenium.webdriver import ActionChains

# %%
menu = driver.find_element(By.CSS_SELECTOR, ".nav")
hidden_submenu = driver.find_element(By.CSS_SELECTOR, ".nav-link ")

actions = ActionChains(driver)
actions.move_to_element(menu)
actions.click(hidden_submenu)
actions.perform()

# %%
info_url=[]

for i in driver.find_elements(By.XPATH,'//a[@class="match-center-btn ng-scope"]'):
    info_url.append(i.get_attribute('href'))

# %%
info_url
# Out:
# ['https://www.bcci.tv/events/100/australia-tour-of-india-test-series-2022-23/match/740/1st-test',
#  'https://www.bcci.tv/events/104/icc-womens-t20-world-cup-2023/match/754/1st-t20i',
#  'https://www.bcci.tv/events/104/icc-womens-t20-world-cup-2023/match/755/2nd-t20i',
#  'https://www.bcci.tv/events/100/australia-tour-of-india-test-series-2022-23/match/741/2nd-test',
#  'https://www.bcci.tv/events/104/icc-womens-t20-world-cup-2023/match/756/3rd-t20i',
#  'https://www.bcci.tv/events/104/icc-womens-t20-world-cup-2023/match/757/4th-t20i',
#  'https://www.bcci.tv/events/100/australia-tour-of-india-test-series-2022-23/match/742/3rd-test',
#  'https://www.bcci.tv/events/100/australia-tour-of-india-test-series-2022-23/match/743/4th-test']

# %%
Match_title=[]
Series=[]
Place=[]
Date=[]
Time=[]

# %%
for i in info_url:
    driver.get(i)
    time.sleep(2)
    try:
        mt=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/div[3]/div[7]/div[3]/div/div[1]/div/div[1]/div[1]')
        Match_title(mt.text)
    except NoSuchElementException:
        Match_title.append("-")

# %%
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="ng-binding"]'):
    Match_title.append(i.text)
except NoSuchElementException:
    Match_title.append("-")

# %%
Match_title
# Out:
# ['AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23',
#  'ICC WOMENS T20 WORLD CUP 2023',
#  'ICC WOMENS T20 WORLD CUP 2023',
#  'AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23',
#  'ICC WOMENS T20 WORLD CUP 2023',
#  'ICC WOMENS T20 WORLD CUP 2023',
#  'AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23',
#  'AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23']

# %%
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]'):
    Series.append(i.text)
except NoSuchElementException:
    Series.append("-")

# %%
Series
# Out:
# ['1st Test -',
#  '1st T20I -',
#  '2nd T20I -',
#  '2nd Test -',
#  '3rd T20I -',
#  '4th T20I -',
#  '3rd Test -',
#  '4th Test -']

# %%
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="ng-binding ng-scope"]'):
    Place.append(i.text)
except NoSuchElementException:
    Place.append("-")

# %%
Place
# Out:
# ['Vidarbha Cricket Association Stadium,',
#  'Newlands,',
#  'Newlands,',
#  'Arun Jaitley Stadium,',
#  "St George's Park,",
#  "St George's Park,",
#  'Himachal Pradesh Cricket Association Stadium,',
#  'Narendra Modi Stadium,']

# %%
try:
    for i in driver.find_elements(By.XPATH,'//div[@class="match-card-left match-schedule"]'):
    Date.append(i.text)
except NoSuchElementException:
    Date.append("-")

# %%
Date
# Out:
# ['9 FEB 2023',
#  '12 FEB 2023',
#  '15 FEB 2023',
#  '17 FEB 2023',
#  '18 FEB 2023',
#  '20 FEB 2023',
#  '1 MAR 2023',
#  '9 MAR 2023']

# %%
try:
    for i in driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]'):
    Time.append(i.text)
except NoSuchElementException:
    Time.append("-")

# %%
Time
# Out:
# ['9:30 AM IST',
#  '6:30 PM IST',
#  '6:30 PM IST',
#  '9:30 AM IST',
#  '6:30 PM IST',
#  '6:30 PM IST',
#  '9:30 AM IST',
#  '9:30 AM IST']

# %%
print(len(Match_title),len(Series),len(Place),len(Date),len(Time))
# Out:
# 8 8 8 8 8

# %%
df=pd.DataFrame({"Match_title":Match_title,"Series":Series,"Place":Place,"Date":Date,"Time":Time})
df
# Out:
#                                    Match_title      Series  \
# 0  AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23  1st Test -
# 1                ICC WOMENS T20 WORLD CUP 2023  1st T20I -
# 2                ICC WOMENS T20 WORLD CUP 2023  2nd T20I -
# 3  AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23  2nd Test -
# 4                ICC WOMENS T20 WORLD CUP 2023  3rd T20I -
# 5                ICC WOMENS T20 WORLD CUP 2023  4th T20I -
# 6  AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23  3rd Test -
# 7  AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23  4th Test -
#
#                                            Place         Date         Time
# 0          Vidarbha Cricket Association Stadium,   9 FEB 2023  9:30 AM IST
# 1                                      Newlands,  12 FEB 2023  6:30 PM IST
# 2                                      Newlands,  15 FEB 2023  6:30 PM IST
# 3                          Arun Jaitley Stadium,  17 FEB 2023  9:30 AM IST
# ...

# %%
driver.close()

# %% [markdown]
# Question.3) Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/

# %% [markdown]
# Khushboo Garg Mam has asked to skip this question.

# %% [markdown]
# Question.7) Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/

# %%
driver=webdriver.Chrome(r"C:\Users\jaisw\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.imdb.com/list/ls095964455")

# %%
Name=[]
Year=[]
Genre=[]
Run_time=[]

# %%
try:
    for i in driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]'):
        Name.append(i.text.split("\n",)[0])
    
except NoSuchElementException:
    Name.append("-")

# %%
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="lister-item-year text-muted unbold"]'):
        Year.append(i.text)
    
except NoSuchElementException:
    Year.append("-")

# %%
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="genre"]'):
        Genre.append(i.text)
    
except NoSuchElementException:
    Genre.append("-")

# %%
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="runtime"]'):
        Run_time.append(i.text)
    
except NoSuchElementException:
    Run_time.append("-")

# %%
Vote=[]
try:
    for i in driver.find_elements(By.XPATH,'//span[@name="nv"]'):
        Vote.append(i.text)
    
except NoSuchElementException:
    Vote.append("-")

# %%
RT=[]
try:
    for i in driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]'):
        RT.append(i.text)
    
except NoSuchElementException:
    RT.append("-")

# %%
df3=pd.DataFrame({"Name":Name,"Year":Year,"Genre":Genre,"Run_time":Run_time,"Vote":Vote,"Ratings":RT})
df3
# Out:
#                                      Name         Year  \
# 0          1. Game of Thrones (2011–2019)  (2011–2019)
# 1          2. Stranger Things (2016–2024)  (2016–2024)
# 2         3. The Walking Dead (2010–2022)  (2010–2022)
# 3           4. 13 Reasons Why (2017–2020)  (2017–2020)
# 4                  5. The 100 (2014–2020)  (2014–2020)
# ..                                    ...          ...
# 95                  96. Reign (2013–2017)  (2013–2017)
# 96     97. A Series of Unfortunate Events
# 97            98. Criminal Minds (2005– )     (2005– )
# 98  99. Scream: The TV Series (2015–2019)  (2015–2019)
# 99        100. The Haunting of Hill House
#
#                        Genre Run_time       Vote Ratings
# 0   Action, Adventure, Drama   57 min  2,122,741     9.2
# 1     Drama, Fantasy, Horror   51 min  1,210,750     8.7
# 2    Drama, Horror, Thriller   44 min  1,006,777     8.1
# 3   Drama, Mystery, Thriller   60 min    297,072     7.5
# ...

# %%
driver.close()

# %% [markdown]
# Question.6) Scrape the details of Highest sellingnovels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/

# %%
driver=webdriver.Chrome(r"C:\Users\jaisw\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
Book=[]
Author_name=[]
Volumes_sold=[]
Publisher=[]
Genre=[]

# %%
try:
    for i in driver.find_elements(By.XPATH,'//td[@class="left"]'):
        Book.append(i.text)
       
    
except NoSuchElementException:
    Book.append("-")

# %%
Book
# Out:
# ['Da Vinci Code,The',
#  'Brown, Dan',
#  '5,094,805',
#  'Transworld',
#  '2',
#  'Harry Potter and the Deathly Hallows',
#  'Rowling, J.K.',
#  '4,475,152',
#  'Bloomsbury',
#  '3',
#  "Harry Potter and the Philosopher's Stone",
#  'Rowling, J.K.',
#  '4,200,654',
#  'Bloomsbury',
#  '4',
#  'Harry Potter and the Order of the Phoenix',
#  'Rowling, J.K.',
#  '4,179,479',
#  'Bloomsbury',
#  '5',
#  'Fifty Shades of Grey',
#  'James, E. L.',
#  '3,758,936',
#  'Random House',
#  '6',
#  'Harry Potter and the Goblet of Fire',
#  'Rowling, J.K.',
#  '3,583,215',
#  'Bloomsbury',
#  '7',
#  'Harry Potter and the Chamber of Secrets',
#  'Rowling, J.K.',
#  '3,484,047',
#  'Bloomsbury',
#  '8',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Rowling, J.K.',
#  '3,377,906',
#  'Bloomsbury',
#  '9',
#  'Angels and Demons',
#  'Brown, Dan',
#  '3,193,946',
#  'Transworld',
#  '10',
#  "Harry Potter and the Half-blood Prince:Children's Edition",
#  'Rowling, J.K.',
#  '2,950,264',
# ...

# %%
try:
    for i in driver.find_elements(By.XPATH,'//td[@class="last left"]'):
        Genre.append(i.text)
       
    
except NoSuchElementException:
    Genre.append("-")

# %%
Genre
# Out:
# ['Crime, Thriller & Adventure',
#  "Children's Fiction",
#  "Children's Fiction",
#  "Children's Fiction",
#  'Romance & Sagas',
#  "Children's Fiction",
#  "Children's Fiction",
#  "Children's Fiction",
#  'Crime, Thriller & Adventure',
#  "Children's Fiction",
#  'Romance & Sagas',
#  'Young Adult Fiction',
#  'Crime, Thriller & Adventure',
#  'Romance & Sagas',
#  'Crime, Thriller & Adventure',
#  'Young Adult Fiction',
#  'Crime, Thriller & Adventure',
#  'Young Adult Fiction',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'Crime, Thriller & Adventure',
#  'Popular Science',
#  'Crime, Thriller & Adventure',
#  'Young Adult Fiction',
#  'Picture Books',
#  'Picture Books',
#  'Food & Drink: General',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'Crime, Thriller & Adventure',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
# ...

# %%
driver.close()

# %% [markdown]
# Question.4) Scrape the details of trending repositories on Github.com.
# Url = https://github.com/

# %%
driver=webdriver.Chrome(r"C:\Users\jaisw\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://github.com")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[1]/div[2]/button/span/span')
search.click()

# %%
searchs=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')
searchs.click()

# %%
Repository=[]
Repository_des=[]
Cont=[]
Language=[]

# %%
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="text-normal"]'):
        Repository.append(i.text)
       
    
except NoSuchElementException:
    Repository.append("-")

# %%
try:
    for i in driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]'):
        Repository_des.append(i.text)
       
    
except NoSuchElementException:
    Repository_des.append("-")

# %%
Contribution=[]
try:
    for i in driver.find_elements(By.XPATH,'//div[@class="f6 color-fg-muted mt-2"]'):
        
        Contribution.append(i.text.split(" ")[1])
        
       
    
except NoSuchElementException:
    Contribution.append("-")

# %%
try:
    for i in driver.find_elements(By.XPATH,'//span[@itemprop="programmingLanguage"]'):
        Language.append(i.text)
       
    
except NoSuchElementException:
    Language.append("-")

# %%
df5=pd.DataFrame({"Repository":Repository[0:22],"Repository Description":Repository_des[0:22],"Contribution":Contribution[0:22],"Language":Language[0:22]})
df5
# Out:
#         Repository                             Repository Description  \
# 0     acikkaynak /  Wildebeest is an ActivityPub and Mastodon-comp...
# 1   guaguaguaxia /  A WhatsApp client library for NodeJS that conn...
# 2     cloudflare /                                      current-front
# 3    pedroslopez /  Your self-hosted, globally interconnected micr...
# 4     acikkaynak /  This repo includes ChatGPT prompt curation to ...
# 5       mastodon /    Reverse engineered API of Microsoft's Bing Chat
# 6              f /  current back Deprem.io is a platform to help w...
# 7      acheong08 /  Open source virtual / remote desktop infrastru...
# 8     acikkaynak /  An Open Source Financial Switch to make Paymen...
# 9       rustdesk /  📚 Papers & tech blogs by companies sharing the...
# 10        juspay /  This is the starting codebase that will be use...
# 11     eugeneyan /  iOS 14.0-15.7.1 & 16.0-16.1.2 MacDirtyCow ToolBox
# ...

# %%
driver.close()

# %% [markdown]
# Question.5) Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/

# %%
driver=webdriver.Chrome(r"C:\Users\jaisw\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https:/www.billboard.com")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a')
search.click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 search=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a')
# ----> 2 search.click()
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:93, in WebElement.click(self)
#      91 def click(self) -> None:
#      92     """Clicks the element."""
# ---> 93     self._execute(Command.CLICK_ELEMENT)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:410, in WebElement._execute(self, command, params)
#     408     params = {}
#     409 params["id"] = self._id
# --> 410 return self._parent.execute(command, params)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
# ...

# %%
Song=[]
Artist=[]
Lastweekrank=[]
Peakrank=[]
Weeksonboard=[]

# %%
try:
    for i in driver.find_elements(By.XPATH,'//h3[@class="c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only"]'):
        Song.append(i.text)
       
    
except NoSuchElementException:
    Song.append("-")

# %%
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]'):
        Artist.append(i.text)
       
    
except NoSuchElementException:
    Artist.append("-")

# %%
URL=[]
for i in driver.find_elements(By.XPATH,'//a[@class="c-link  lrv-a-unstyle-link lrv-u-background-color-brand-secondary-dark lrv-u-color-grey-lightest lrv-u-color-grey-lightest:hover lrv-u-width-100p lrv-u-text-align-center lrv-a-hover-effect lrv-u-background-color-grey-dark:hover a-font-accent-fancy lrv-u-font-size-20 u-padding-tb-15 u-letter-spacing-0112 lrv-a-icon-after a-icon-magazine lrv-u-justify-content-center lrv-u-align-items-center lrv-a-unstyle-link u-width-100p@tablet u-width-235@mobile-max lrv-u-margin-t-050@mobile-max u-background-color-white@mobile-max u-color-black@mobile-max lrv-u-border-a-1@mobile-max lrv-u-border-color-brand-accent-red u-line-height-1"]'):
    URL.append(i.get_attribute("href"))

# %%
URL
# Out:
# ['https://www.billboard.com/charts/hot-100/']

# %%
for i in URL:
    driver.get(i)
    time.sleep(2)
    try:
        br=driver.find_element(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li[4]/span[1]')
        Lastweekrank.append(br.text)
    except NoSuchElementException:
        Lastweekrank.append("-")

# %%
peak_rank=[]

# %%
for i in URL:
    driver.get(i)
    time.sleep(2)
    try:
        for i in driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li[5]/span[1]'):
            peak_rank.append(i.text)
    

    except NoSuchElementException:
        peak_rank.append("-")

# %%
Weeks=[]

# %%
for i in URL:
    driver.get(i)
    time.sleep(2)
    try:
        for i in driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li[6]/span[1]'):
            Weeks.append(i.text)
    
    

    except NoSuchElementException:
        Weeks.append("-")

# %%
print(len(Song),len(Artist),len(Lastweekrank),len(peak_rank),len(Weeks))
# Out:
# 99 99 203 100 100

# %%
df7=pd.DataFrame({"Song":Song[0:99],"Artist":Artist[0:99],"Lastweekrank":Lastweekrank[0:99],"peak_rank":peak_rank[0:99],"Weeks":Weeks[0:99]})
df7
# Out:
#                            Song                                Artist  \
# 0                     Kill Bill                                   SZA
# 1                      Creepin'  Metro Boomin, The Weeknd & 21 Savage
# 2                     Anti-Hero                          Taylor Swift
# 3                        Unholy                Sam Smith & Kim Petras
# 4                   Die For You                            The Weeknd
# ..                          ...                                   ...
# 94                      Hey Mor                  Ozuna Featuring Feid
# 95                Gato de Noche                Nengo Flow & Bad Bunny
# 96               Heart To Heart                           Mac DeMarco
# 97  Never Gonna Not Dance Again                                  P!nk
# 98       Dancin' In The Country                         Tyler Hubbard
#
#    Lastweekrank peak_rank Weeks
# 0
# 1
# 2
# 3
# 4
# ..          ...       ...   ...
# 94
# 95
# 96
# 97
# 98
#
# ...

# %%
driver.close()

# %% [markdown]
# Question.8) Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/

# %%
driver=webdriver.Chrome(r"C:\Users\jaisw\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://archive.ics.uci.edu")

# %%
search=driver.find_element(By.XPATH,'/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b')
search.click()

# %%
Dataset_name=[]
Data_type=[]
Task=[]
Attribute_type=[]
No_of_instances=[]
No_of_attribute=[]
Year=[]

# %%
try:
    info=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    for i in info[1:]:
        Data_type.append(i.text)
         
except NoSuchElementException:
    data_type.append("No information")

# %%
Data_type
# Out:
# ['Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Univariate, Text ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate, Data-Generator ',
#  'Multivariate ',
#  'Multivariate ',
#  'Domain-Theory ',
#  'Univariate, Time-Series ',
#  'Multivariate, Spatial ',
#  'Multivariate ',
#  'Multivariate, Domain-Theory ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate, Time-Series ',
#  'Data-Generator ',
#  ' ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate, Time-Series ',
# ...

# %%
try:
    infor=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[2]/td[1]/table/tbody/tr/td[2]")
    for i in infor[1:]:
        Task.append(i.text)
         
except NoSuchElementException:
    Task.append("No information")

# %%
Task
# Out:
# ['Classification ', 'Classification ']

# %%
url=[]
for i in driver.find_elements(By.XPATH,'//p[@class="normal"]'):
    url.append(i.get_attribute("href"))

# %%
try:
    for i in driver.find_elements(By.XPATH,'//p[@class="normal"]'):
        Dataset_name.append(i.text)
    
    

except NoSuchElementException:
    Dataset_name.append("-")

# %%
Details=[i.text.split('\n') for i in driver.find_elements(By.XPATH,'//p[@class="normal"]')]

try:
    for i in Details:
        Data_type.append(i[0])
        Task.append(i[-1])
        
except NoSuchElementException:
    Data_type.append('-')
    Task.append('-')

# %%
Data_type
# Out:
# ['Classification (466)',
#  'Categorical (38)',
#  'Multivariate (480)',
#  'Life Sciences (147)',
#  'Less than 10 (166)',
#  'Less than 100 (38)',
#  'Matrix (439)',
#  'Table View  List View',
#  'Classification (466)',
#  'Categorical (38)',
#  'Multivariate (480)',
#  'Life Sciences (147)',
#  'Less than 10 (166)',
#  'Less than 100 (38)',
#  'Matrix (439)',
#  'Table View  List View',
#  'Abalone',
#  'Multivariate ',
#  'Classification ',
#  'Categorical, Integer, Real ',
#  '4177 ',
#  '8 ',
#  '1995 ',
#  'Adult',
#  'Multivariate ',
#  'Classification ',
#  'Categorical, Integer ',
#  '48842 ',
#  '14 ',
#  '1996 ',
#  'Annealing',
#  'Multivariate ',
#  'Classification ',
#  'Categorical, Integer, Real ',
#  '798 ',
#  '38 ',
#  ' ',
#  'Anonymous Microsoft Web Data',
#  ' ',
#  'Recommender-Systems ',
#  'Categorical ',
#  '37711 ',
#  '294 ',
#  '1998 ',
#  'Arrhythmia',
#  'Multivariate ',
#  'Classification ',
#  'Categorical, Integer, Real ',
#  '452 ',
#  '279 ',
# ...

# %%
Task
# Out:
# ['Regression (151)',
#  'Numerical (422)',
#  'Univariate (30)',
#  'Physical Sciences (57)',
#  '10 to 100 (279)',
#  '100 to 1000 (210)',
#  'Non-Matrix (183)',
#  'Other (56)',
#  'Mixed (55)',
#  'Other (21)',
#  'Other (81)',
#  'Greater than 100 (110)',
#  'Greater than 1000 (339)',
#  'Non-Matrix (183)',
#  'Table View  List View',
#  'Abalone',
#  'Multivariate ',
#  'Classification ',
#  'Categorical, Integer, Real ',
#  '4177 ',
#  '8 ',
#  '1995 ',
#  'Adult',
#  'Multivariate ',
#  'Classification ',
#  'Categorical, Integer ',
#  '48842 ',
#  '14 ',
#  '1996 ',
#  'Annealing',
#  'Multivariate ',
#  'Classification ',
#  'Categorical, Integer, Real ',
#  '798 ',
#  '38 ',
#  ' ',
#  'Anonymous Microsoft Web Data',
#  ' ',
#  'Recommender-Systems ',
#  'Categorical ',
#  '37711 ',
#  '294 ',
#  '1998 ',
#  'Arrhythmia',
#  'Multivariate ',
#  'Classification ',
#  'Categorical, Integer, Real ',
#  '452 ',
#  '279 ',
#  '1998 ',
#  'Artificial Characters',
# ...
